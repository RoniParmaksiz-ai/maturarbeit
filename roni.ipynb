# %%
import requests
base_url = "https://ws-old.parlament.ch/"
url_de = "/sessions?lang=de"
sessions_url = f"{base_url}//{url_de}"
test_factions_url = f"{base_url}/factions/{url_de}"


def get_transcript_data(transcripts):
    response = requests.get(transcripts_url)
    if response.status_code == 200:
        print("Successfully retrieved transcript data.")
    else:
        print("Failed to retrieve transcript data.")

def get_faction_data(factions):
    response_1 = requests.get(test_factions_url)
    if response_1.status_code == 200:
        print("Successfully retrieved faction data.")
    else:
        print("Failed to retrieve faction data.")

transcripts_url = requests.get(transcripts_url)

if transcripts_url.status_code == 200:
    print("Successfully retrieved transcript data.")
else:
    print("Failed to retrieve transcript data.")

# this dont work rather use swissparlpy for the training data
# Out:
# Failed to retrieve transcript data.
