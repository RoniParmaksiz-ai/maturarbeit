# %%
import swissparlpy as spp
from swissparlpy import SwissParlClient
import pandas as pd

opd_client = SwissParlClient(backend="openparldata")
data_tables = opd_client.get_tables()

test_speeches = opd_client.get_glimpse("speeches")

print(test_speeches)

test_variables = opd_client.get_variables("persons")

test_speeches.count

test_speeches[0]
# Out:
# ...
# {'id': 2823394,
#  'url_api': 'https://api.openparldata.ch/v1/speeches/2823394',
#  'body_key': 'ZH',
#  'external_id': 'ca5d9f7e-3eec-4f9b-b4aa-e9531ddf56b9',
#  'body_id': 275,
#  'person_id': 17711,
#  'person_role': None,
#  'person_role_de': 'Präsidium',
#  'person_role_fr': 'Präsidium',
#  'person_role_it': 'Präsidium',
#  'meeting_id': None,
#  'date_start': '2026-09-21T08:16:39',
#  'date_end': None,
#  'text_content_de': None,
#  'text_content_fr': None,
#  'text_content_it': None,
#  'type_external_id': 'SEGMENT_TYPE_SPEAKER',
#  'type_external_de': None,
#  'type_external_fr': None,
#  'type_external_it': None,
#  'affair_id': None,
#  'url': 'https://zh.recapp.ch/shareparl?agendaItemUid=c08bb828-193b-4cd6-a87d-a194bdb0af95&segmentUidca5d9f7e-3eec-4f9b-b4aa-e9531ddf56b9',
#  'audio_url': None,
#  'video_url': 'https://recapp-prod-zh-viewer.s3.ewstorage.ch/mediaDash/6aabe4d5d44ba4f128d2caa8_converted_media_file_1789984249181.mp4',
#  'meeting_external_id': None,
# ...
