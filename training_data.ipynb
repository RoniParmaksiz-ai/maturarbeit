# %%
from pandas import test
import swissparlpy as spp
from swissparlpy import SwissParlClient
import pandas as pd

odata_client = SwissParlClient(backend="odata")
data_tables = odata_client.get_tables()

test_transcripts = odata_client.get_glimpse("Transcript")

test_transcripts_df = pd.DataFrame(test_transcripts)

print(test_transcripts_df)
# Out:
#    ID Language  IdSubject VoteId  PersonNumber  Type  \
# 0   1       DE          1                  498     1
# 1   1       EN          1                  498     1
# 2   1       FR          1                  498     1
# 3   1       IT          1                  498     1
# 4   1       RM          1                  498     1
#
#                                                 Text  \
# 0  <pd_text><p>La séance d'aujourd'hui s'ouvre so...
# 1  <pd_text><p>La séance d'aujourd'hui s'ouvre so...
# 2  <pd_text><p>La séance d'aujourd'hui s'ouvre so...
# 3  <pd_text><p>La séance d'aujourd'hui s'ouvre so...
# 4  <pd_text><p>La séance d'aujourd'hui s'ouvre so...
#
#   MeetingCouncilAbbreviation MeetingDate  MeetingVerbalixOid  ...  \
# 0                          N    19991206                 637  ...
# 1                          N    19991206                 637  ...
# 2                          N    19991206                 637  ...
# ...
